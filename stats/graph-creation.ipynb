# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import csv 
import itertools
from ast import literal_eval

# %%
# DATA
data = pd.read_csv('./tagged_books.csv')
data = data.dropna()

# %%
data["Genres"] = data["Genres"].apply(literal_eval)
data.Genres
# Out:
# 1     {sci-fi, fiction, horror, action-adventure, co...
# 2     {sci-fi, fiction, horror, action-adventure, co...
# 3     {sci-fi, fiction, horror, action-adventure, co...
# 4     {female-authors, angels, sci-fi, diverse, fict...
# 5              {action-adventure, fantasy, fiction, ya}
# 6     {fiction, chicklit, contemporary, adult, fantasy}
# 7     {angels, sci-fi, fiction, horror, action-adven...
# 9     {sci-fi, diverse, fiction, superhero, horror, ...
# 10    {sci-fi, diverse, fiction, superhero, horror, ...
# 11    {sci-fi, fiction, superhero, horror, action-ad...
# 12    {sci-fi, diverse, fiction, horror, lgbt, ya, f...
# 13    {sci-fi, fiction, horror, action-adventure, ya...
# 15    {diverse, fiction, lgbt, action-adventure, con...
# 16    {diverse, fiction, lgbt, action-adventure, con...
# 19    {female-authors, diverse, fiction, contemporar...
# 20    {female-authors, sci-fi, diverse, fiction, hor...
# 22    {sci-fi, fiction, ya, action-adventure, dystop...
# ...

# %%
genres = set(itertools.chain.from_iterable(data.Genres))

# %%
data
# Out:
#     Unnamed: 0   Book Id                                              Title  \
# 1            1  26892110                          The Library at Mount Char
# 2            2  37638128      Of Blood and Bone (Chronicles of The One, #2)
# 3            3  34311452               Year One (Chronicles of The One, #1)
# 4            4  41961994   The Library of the Unwritten (Hell's Library #1)
# 5            5  12159908                                         Dragonborn
# 6            6  46225061                        The Two Lives of Lydia Bird
# 7            7   7171637         Clockwork Angel (The Infernal Devices, #1)
# 9            9  42771754                          Supernova (Renegades, #3)
# 10          10  35425827                        Archenemies (Renegades, #2)
# 11          11  52486678                  Chosen Ones (The Chosen Ones, #1)
# 12          12  35391237           Five  Dark Fates (Three Dark Crowns, #4)
# ...
